# %% [markdown]
# # Assignment 2

# %% [markdown]
# ### Q1  Practise Dictionary,Tuple,Set

# %%
# create a dictionary 
dic={
    "name":"Ravi Kumar",
    "age":24,
    "course":"B.Tech"
}
print(dic)
print(dic.keys())
print(dic.values())
print(dic.items())
# Out:
# {'name': 'Ravi Kumar', 'age': 24, 'course': 'B.Tech'}
# dict_keys(['name', 'age', 'course'])
# dict_values(['Ravi Kumar', 24, 'B.Tech'])
# dict_items([('name', 'Ravi Kumar'), ('age', 24), ('course', 'B.Tech')])

# %%
# nested dictionary
d = {1: 'Program', 2: 'For', 3: {'A': 'Dictionary', 'B': 'In', 'C': 'Python'}} 
print(d[3]["A"])
print(d[3]["B"])
# Out:
# Dictionary
# In

# %%
# dictionary function in the dictionary
d1 = {1: 'Program', 2: 'For', 3: {'A': 'Dictionary', 'B': 'In', 'C': 'Python'}} 
d2=d1.copy()
print(d2)
print(d1.clear())
print(d2.get(1))
print(d2.pop(2))
print(d2.popitem()) # to finding the last inserted key value pair in the output
# Out:
# {1: 'Program', 2: 'For', 3: {'A': 'Dictionary', 'B': 'In', 'C': 'Python'}}
# None
# Program
# For
# (3, {'A': 'Dictionary', 'B': 'In', 'C': 'Python'})

# %% [markdown]
# #### practice of tuples

# %%
## practice of tuple 
python_tuple=("apple","manago","banana")
print(python_tuple[1])
print(python_tuple[-1])
# for loop in the tuple
for i in python_tuple:
    print(i)
python=(1,2,3,4,5,6,7)
print(python[2:5])
python2=()
for i in range(4):
    l=list(python2)
    l.append(i)
print(l)
# Out:
# manago
# banana
# apple
# manago
# banana
# (3, 4, 5)
# [3]

# %%
#update the tupple
python_tuple=("apple","manago","banana")
li=list(python_tuple)
li[1]="kiwi"
li.append("orange")
py=tuple(li)
print(py)
# Out:
# ('apple', 'kiwi', 'banana', 'orange')

# %%
# unpaking in the tuple
fruits=("banana","manago","orange")
(green, yello,blue)=fruits
print(green)
print(yello)
print(blue)
# Out:
# banana
# manago
# orange

# %%
#join in tuple
tuple1=("hey","hello","byee")
tuple2=(1,2,3)
tuple3=tuple1+tuple2
print(tuple3)
# Out:
# ('hey', 'hello', 'byee', 1, 2, 3)

# %% [markdown]
# #### practice of set

# %%
set1={"hey","hello","byee"}
set2={1,2,3,4}
print(set1)
set1.add("yooo")
print(set1)
set1.update(set2)
print(set1)
set3=set1.union(set2)
print(set3)
set4=set1.intersection(set2)
print(set4)
set5=set1 & set2
print(set5)
# Out:
# {'byee', 'hey', 'hello'}
# {'yooo', 'byee', 'hey', 'hello'}
# {1, 2, 3, 4, 'byee', 'yooo', 'hey', 'hello'}
# {1, 2, 3, 4, 'byee', 'yooo', 'hey', 'hello'}
# {1, 2, 3, 4}
# {1, 2, 3, 4}

# %% [markdown]
# # Q2 2) Write a function for basic math operations like add multiply subtract divide and use this in your program, take 2 number input from user.

# %%
a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))

print("""
1. Addition
2. Subtraction
3. Multiplication
4. Division
5. Exit
""")

choice = int(input("Enter your choice: "))

match choice:

    case 1:
        def summ(a, b):
            print("Addition =", a + b)

        summ(a, b)

    case 2:
        def sub(a, b):
            print("Subtraction =", a - b)

        sub(a, b)

    case 3:
        def mul(a, b):
            print("Multiplication =", a * b)

        mul(a, b)

    case 4:
        def div(a, b):
            if b == 0:
                print("Division by zero not possible")
            else:
                print("Division =", a / b)

        div(a, b)

    case 5:
        print("Program exited...")

    case _:
        print("Invalid choice")
# Out:
# Enter the value of a:  10
# Enter the value of b:  2
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice:  1
# Addition = 12

# %% [markdown]
# ### Q3 Write a program to check Palindrome Number For example Number 12321 is a Palindrome Number, because 12321 is equal to its reverse Number 12321.Steps for checking Palindrome number
# ### 1. Find reverse of the given number.
# ### 2. Compare that number with the reverse number.
# ### 3. If number and its reverse is equal then it is a Palindrome Number otherwise not.

# %%
number = int(input("Enter the number: "))
num=number
rev = 0
while number > 0:
    r = number % 10
    rev = rev * 10 + r
    number = number // 10
    
print("Reverse =", rev)
if rev==num:
    print("number is plaindrome")
else:
    print("number is not plaindrom")
# Out:
# Enter the number:  1221
# Reverse = 1221
# number is plaindrome
