# %% [markdown]
# # Summer Internship Assignment 1 (Python Practice)

# %% [markdown]
# ### Q1.Write a python program that takes in a student name, class. It should also take in five subject marks of the students and find the total mark and percentage. Display a result in such a way that their name, class,  and percentage are printed.

# %%
Student_name=input("Enter the student name:")
Student_class=input("Class_name:")
# take five subject marks
Math_marks=float(input("Enter the Marks of Math:"))
Eng_marks=float(input("enter the english marks:"))
hindi_marks=float(input("enter the hindi marks:"))
science_marks=float(input("enter the science marks:"))
DE_marks=float(input("enter the DE marks:"))

total_marks=Math_marks+Eng_marks+hindi_marks+science_marks+DE_marks
Percentage= (total_marks/500)*100
print("Student name is:",Student_name)
print("Student class is:",Student_class)
print("total marks os student:",total_marks)
print("percentage:",Percentage,"%")
# Out:
# Enter the student name: Ravi Kumar
# Class_name: 12th
# Enter the Marks of Math: 90
# enter the english marks: 91
# enter the hindi marks: 92
# enter the science marks: 93
# enter the DE marks: 94
# Student name is: Ravi Kumar
# Student class is: 12th
# total marks os student: 460.0
# percentage: 92.0 %

# %% [markdown]
# ### Q2..input 2 strings concatinate them and store in another variable. then perform generally used string methods on it like lower(), upper(), title(), swapcase(), capitalize(), casefold(), center(), count(), endswith(), find(), isalnum(), isdigit(), isnumeric(), isspace(), replace()

# %%
#upper and lowe case
str1=input("enter the first string")
str2=input("enter the second string")
print(str1.upper())
print(str2.upper())
print(str1.lower())
print(str2.lower())
print(str1.
# Out:
# enter the first string Hey
# enter the second string I Am python
# HEY
# I AM PYTHON
# hey
# i am python

# %%
#us eof swapcase
str1=input("enter the first string")
str2=input("enter the second string")
print(str1.swapcase())
print(str2.swapcase())
print(str1.capitalize())
print(str2.capitalize())
print(str1.casefold()) # it handle some international character Hey My NaMe is PYthon ANd i am verY Simple
print(str2.casefold())
print(str1.count("y"))
print(str2.count("e"))
# Out:
# enter the first string Hey My NaMe is PYthon
# enter the second string ANd i am verY Simple
# hEY mY nAmE IS pyTHON
# anD I AM VERy sIMPLE
# Hey my name is python
# And i am very simple
# hey my name is python
# and i am very simple
# 2
# 2

# %%
# concatinate the string
str1=input("enter the first string")
str2=input("enter the second string")
print(str1+" "+str2)
# Out:
# enter the first string hey
# enter the second string python
# hey python

# %%
#endwith() and find()
str1=input("enter the first string")
str2=input("enter the second string")
print(str1.endswith("n"))
print(str2.find("l"))
# Out:
# enter the first string clon
# enter the second string velly
# True
# 2

# %%
#isalnum(), isdigit(), isnumeric(), isspace(), replace()
str1=input("enter the first string")
str2=input("enter the second string")
print(str1.isalnum())
print(str2.isdigit())
print(str1.isnumeric())
print(str2.replace("is","hard"))
# Out:
# enter the first string hello
# enter the second string it is work
# True
# False
# False
# it hard work

# %% [markdown]
# ### Q3.. Do practise of assignment operators

# %%
a=int(input("enter the number"))
b=int(input("enter the number"))
a+=b # += operator
print(a)
# Out:
# enter the number 2
# enter the number 3
# 5

# %%
a=int(input("enter the number"))
b=int(input("enter the number"))
a-=b # -= operator
print(a)
# Out:
# enter the number 2
# enter the number 3
# -1

# %%
a=int(input("enter the number"))
b=int(input("enter the number"))
a*=b # *= operator
print(a)
# Out:
# enter the number 2
# enter the number 3
# 6

# %%
a=int(input("enter the number"))
b=int(input("enter the number"))
a**=b # **= operator
print(a)
# Out:
# enter the number 2
# enter the number 4
# 16

# %%
a=int(input("enter the number"))
b=int(input("enter the number"))
a/=b # /= operator
print(a)
# Out:
# enter the number 4
# enter the number 2
# 2.0

# %%
a=int(input("enter the number"))
b=int(input("enter the number"))
a%=b # %= operator
print(a)
# Out:
# enter the number 5
# enter the number 10
# 5

# %% [markdown]
# ### Q4 In your last program where you find the total and percentage of a student's marks of 5 subject, find the grade of the student using conditional statement. Eg. grade 'A' if percentage is greator than or equals to 60, 'B' for  percentage is greator than or equals to 50 and less than 60,  'C' for  percentage is greator than or equals to 40 and less than 50,  'D' for  percentage is greator than or equals to 33 and less than 40, otherwise 'Fail'

# %%
# take 5 sub marks input
DMLA=float(input("enter the DMLA marks:"))
CN=float(input("enter the CN Marks:"))
CAM=float(input("enter the CAM marks:"))
FSD=float(input("enter the fsd marks:"))
MEFA=float(input("enter the mefa marks:"))

total=DMLA+CN+CAM+FSD+MEFA
percentage=(total/500)*100
print("total Marks:",total)
print("Percentage:",percentage)
if(percentage>=60):
    print("Grade: A 🥇")
elif (percentage>=50)and(percentage<60):
    print("Grade: B")
elif (percentage>=40)and(percentage<50):
    print("Grade: C")
elif(percentage>=33)and(percentage<40):
    print("Grade: D")
else:
    print("FAIL: Better Luck next time👍👍👍")
# Out:
# enter the DMLA marks: 34
# enter the CN Marks: 90
# enter the CAM marks: 57
# enter the fsd marks: 67
# enter the mefa marks: 34
# total Marks: 282.0
# Percentage: 56.39999999999999
# Grade: B
